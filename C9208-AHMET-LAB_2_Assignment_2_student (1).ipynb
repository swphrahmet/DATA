# %% [markdown]
# # WITH SEABORN

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
# 1. Box and Swarm Plots in kill data
# 1. Most dangerous cities
# 1. Most dangerous states
# 1. Having mental ilness or not for killed people
# 1. Threat types
# 1. Flee types
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
kill = pd.read_csv('PoliceKillingsUS (2).csv', encoding="windows-1252")

# %%
kill.head(5)
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill.shape
# Out:
# (2535, 14)

# %%
kill.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %%
kill.dropna(inplace=True)

# %%
kill.shape
# Out:
# (2254, 14)

# %% [markdown]
# ## 1a: Box plot of age in both genders separeted by manner of death.

# %%
kill.head(5)
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# ...

# %%
kill["manner_of_death"].unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# **INSTRUCTION: Demonstrate the Qurtiles of age in both genders separeted by manner of death.**

# %%
# with seaborn
sns.boxplot(x = "gender", y = "age", hue="manner_of_death", data=kill)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='age'>

# %% [markdown]
# ## 1b: Swarm Plot

# %% [markdown]
# **INSTRUCTION: Demonstrate the age in both genders separeted by manner of death by a swarm plot.**

# %%
# with seaborn
plt.figure(figsize=(10,6))
sns.swarmplot(x = "gender", y="age", data=kill, hue="manner_of_death");

# %% [markdown]
# ## 2: Plot 12 most dangerous cities

# %%
dang = kill.city.value_counts().head(12)
dang
# Out:
# Los Angeles     35
# Phoenix         28
# Houston         24
# Chicago         22
# Austin          18
# Las Vegas       17
# Columbus        16
# San Antonio     15
# Miami           15
# St. Louis       14
# Indianapolis    14
# Bakersfield     13
# Name: city, dtype: int64

# %%
dang.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
dang.values
# Out:
# array([35, 28, 24, 22, 18, 17, 16, 15, 15, 14, 14, 13], dtype=int64)

# %%
new = pd.DataFrame(dang)
new.index
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
plt.title("Most dangerous cities", color="blue", fontsize = 15)
sns.barplot(x = dang.index, y=dang.values, data=kill)
dang_pos = range(len(dang.index))
plt.xticks(dang_pos, dang.index, rotation=45);

# %%
dang.index & kill.city
# Out:
# Index(['Los Angeles', 'Phoenix', 'Houston', 'Chicago', 'Austin', 'Las Vegas',
#        'Columbus', 'San Antonio', 'Miami', 'St. Louis', 'Indianapolis',
#        'Bakersfield'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
plt.title("Most dangerous cities", color="blue", fontsize = 15)
sns.countplot(x = "city", data = kill, order = kill.city.value_counts().iloc[:12].index)
dang_pos = range(len(dang.index))
plt.xticks(dang_pos, dang.index, rotation=45);

# %% [markdown]
# ## 3: Plot 20 most dangerous states

# %%
kill.sample()
# Out:
#       id             name      date manner_of_death armed   age gender race  \
# 276  362  Jason Lee Evans  12/04/15            shot   gun  32.0      M    W
#
#           city state  signs_of_mental_illness threat_level flee  body_camera
# 276  Salemburg    NC                     True       attack  Car        False

# %%
dang_city = kill.state.value_counts().head(20)
dang_city
# Out:
# CA    366
# TX    200
# FL    136
# AZ    105
# OH     70
# NC     66
# OK     65
# CO     63
# GA     61
# MO     58
# IL     56
# TN     56
# WA     51
# LA     47
# AL     45
# PA     45
# VA     43
# NY     43
# WI     42
# NM     41
# Name: state, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.title("Most dangerous states", color="blue", fontsize = 15)
sns.barplot(x=dang_city.index, y=dang_city.values, data=kill)
dang.city = range(len(dang_city.index))
plt.xticks(dang.city, dang_city.index, rotation=45);

# %%
plt.figure(figsize=(10,6))
plt.title("Most dangerous states", color="blue", fontsize = 15)
sns.countplot(x="city", data=kill, order=kill.city.value_counts().iloc[:20].index)
dang.city = range(len(dang_city.index))
plt.xticks(dang.city, dang_city.index, rotation=45);

# %% [markdown]
# ## 4: Plot Having mental ilness or not for killed people

# %%
illness = kill["signs_of_mental_illness"].value_counts()
illness
# Out:
# False    1681
# True      573
# Name: signs_of_mental_illness, dtype: int64

# %%
illness.values
# Out:
# array([1681,  573], dtype=int64)

# %%
sns.countplot(x = "signs_of_mental_illness", data = kill);

# %% [markdown]
# ## 5: Plot number of Threat Types

# %%
kill["threat_level"].value_counts()
# Out:
# attack          1462
# other            677
# undetermined     115
# Name: threat_level, dtype: int64

# %%
sns.countplot(x="threat_level", data=kill);

# %% [markdown]
# ## 6: Plot number of Flee Types

# %%
kill.flee.value_counts()
# Out:
# Not fleeing    1528
# Car             360
# Foot            278
# Other            88
# Name: flee, dtype: int64

# %%
sns.countplot(x="flee", data=kill);
